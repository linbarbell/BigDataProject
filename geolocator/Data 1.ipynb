# %%
import pandas as pd

# %%
import os

# %%
data = pd.read_csv("merged_data_1.csv")

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'medallion_x', u'hack_license', u'vendor_id', u'rate_code', u'store_and_fwd_flag', u'pickup_datetime', u'dropoff_datetime', u'passenger_count', u'trip_time_in_secs', u'trip_distance', u'pickup_longitude', u'pickup_latitude', u'dropoff_longitude', u'dropoff_latitude', u'pickup_neighborhood', u'pickup_hour', u'dropoff_neighborhood', u'dropoff_hour', u'trip_id', u'medallion_y', u' hack_license', u' vendor_id', u' pickup_datetime', u' payment_type', u' fare_amount', u' surcharge', u' mta_tax', u' tip_amount', u' tolls_amount', u' total_amount'], dtype='object')

# %%
data['fare_p'] = data[' tip_amount'] / data[' fare_amount']

# %%
data
# Out:
#           Unnamed: 0                       medallion_x  \
# 0                  0  89D227B655E5C82AECF13C3F540D4CF4
# 1                  1  0BD7C8F5BA12B88E0B67BED28BEA73D8
# 2                  2  0BD7C8F5BA12B88E0B67BED28BEA73D8
# 3                  3  DFD2202EE08F7A8DC9A57B02ACB81FE2
# 4                  4  DFD2202EE08F7A8DC9A57B02ACB81FE2
# 5                  5  20D9ECB2CA0767CF7A01564DF2844A3E
# 6                  6  496644932DF3932605C22C7926FF0FE0
# 7                  7  0B57B9633A2FECD3D3B1944AFC7471CF
# 8                  8  2C0E91FF20A856C891483ED63589F982
# 9                  9  2D4B95E2FA7B2E85118EC5CA4570FA58
# 10                10  E12F6AF991172EAC3553144A0AF75A19
# 11                11  E12F6AF991172EAC3553144A0AF75A19
# 12                12  78FFD9CD0CDA541F335EF8B38FB494D6
# 13                13  237F49C3ECC11F5024B254268F054384
# 14                14  3349F919AA8AE5DC9C50A3773EA45BD8
# 15                15  3349F919AA8AE5DC9C50A3773EA45BD8
# ...
