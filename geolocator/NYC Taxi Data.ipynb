# %%
import pandas as pd

trip_data = pd.read_csv("trip_data_1.csv")
trip_fare = pd.read_csv("trip_fare_1.csv")
#print(trip_fare)
#print(trip_fare)

# %%
import os
#os.chdir(os.path.dirname(__file__))
print(os.getcwd())
# Out:
# /Users/billyshawsusanto/Documents/BigDataProject/geolocator

# %%
# !pwd
# Out:
# /Users/billyshawsusanto/Documents/BigDataProject/geolocator

# %%
trip_data['trip_id'] = trip_data['medallion'] + '_' + trip_data['pickup_datetime']
trip_fare['trip_id'] = trip_fare['medallion'] + '_' + trip_fare['pickup_datetime']

trip_data.to_csv('trip_data_1_new.csv')
trip_fare.to_csv('trip_fare_1_new.csv')

# %%
trip_data.describe()

# %%
trip_data_geo_1 = pd.read_csv("trip_data_with_geo_1.csv")

# %%
trip_data_geo_1[1:10]
# Out:
#                           medallion                      hack_license  \
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5  20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6  496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7  0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8  2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9  2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# ...

# %%
trip_fare[1:10]
# Out:
#                           medallion                      hack_license  \
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5  20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6  496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7  0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8  2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9  2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
#
#    vendor_id      pickup_datetime  payment_type   fare_amount   surcharge  \
# 1        CMT  2013-01-06 00:18:35           CSH           6.0         0.5
# 2        CMT  2013-01-05 18:49:41           CSH           5.5         1.0
# ...

# %%
trip_data['trip_id'] = trip_data['medallion'] + '_' + trip_data['pickup_datetime']
trip_fare['trip_id'] = trip_fare['medallion'] + '_' + trip_fare[' pickup_datetime']

# %%
trip_data[1:10]
# Out:
#                           medallion                      hack_license  \
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5  20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6  496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7  0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8  2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9  2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# ...

# %%
trip_data_geo_1[1:10]
# Out:
#                           medallion                      hack_license  \
# 1  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2  0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4  DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5  20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6  496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7  0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8  2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9  2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
#
#   vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 1       CMT          1                  N  2013-01-06 00:18:35
# 2       CMT          1                  N  2013-01-05 18:49:41
# 3       CMT          1                  N  2013-01-07 23:54:15
# ...

# %%
trip_data_geo_1['trip_id'] = trip_data_geo_1['medallion'] + '_' + trip_data_geo_1['pickup_datetime']

# %%
trip_data_geo_1
# Out:
#                                  medallion                      hack_license  \
# 0         89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5         20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6         496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7         0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8         2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9         2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10        E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# ...

# %%
trip_fare
# Out:
#                                  medallion                      hack_license  \
# 0         89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5         20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6         496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7         0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8         2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9         2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10        E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# ...

# %%
merged_sample = trip_data_geo_1[1:1000].merge(trip_fare[1:1000], on="trip_id")

# %%
merged_sample
# Out:
#                           medallion_x                      hack_license  \
# 0    0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 1    0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2    DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 3    DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4    20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 5    496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 6    0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 7    2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 8    2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 9    E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 10   E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 11   78FFD9CD0CDA541F335EF8B38FB494D6  E949C583ECF62C8F03FDCE1484954A08
# ...

# %%
merged = trip_data_geo_1.merge(trip_fare, on="trip_id")

# %%
merged[1:10]

# %%
merged = merged[1:]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-776c8ad8a716> in <module>()
# ----> 1 merged = merged[1:]
#
# /Users/billyshawsusanto/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1666         indexer = _convert_to_index_sliceable(self, key)
#    1667         if indexer is not None:
# -> 1668             return self._getitem_slice(indexer)
#    1669
#    1670         if isinstance(key, (Series, np.ndarray, list)):
#
# /Users/billyshawsusanto/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_slice(self, key)
#    1693
#    1694     def _getitem_slice(self, key):
# -> 1695         return self._slice(key, axis=0)
#    1696
#    1697     def _getitem_array(self, key):
#
# /Users/billyshawsusanto/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _slice(self, slobj, axis, typ)
# ...

# %%
merged[1:10000]
# Out:
#                            medallion_x                      hack_license  \
# 1     0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2     0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3     DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4     DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5     20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6     496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7     0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8     2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9     2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10    E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 11    E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 12    78FFD9CD0CDA541F335EF8B38FB494D6  E949C583ECF62C8F03FDCE1484954A08
# ...

# %%
merged.to_csv("merged_data_1.csv")

# %%
merged[1:10000].to_csv("merged_data_sample.csv")

# %%
m = merged[1:100000]

# %%
m
# Out:
#                             medallion_x                      hack_license  \
# 1      0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2      0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3      DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4      DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5      20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6      496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7      0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8      2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9      2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10     E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 11     E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
# 12     78FFD9CD0CDA541F335EF8B38FB494D6  E949C583ECF62C8F03FDCE1484954A08
# ...

# %%
m[1:10]
# Out:
#                          medallion_x                      hack_license  \
# 2   0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3   DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4   DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 5   20D9ECB2CA0767CF7A01564DF2844A3E  598CCE5B9C1918568DEE71F43CF26CD2
# 6   496644932DF3932605C22C7926FF0FE0  513189AD756FF14FE670D10B92FAF04C
# 7   0B57B9633A2FECD3D3B1944AFC7471CF  CCD4367B417ED6634D986F573A552A62
# 8   2C0E91FF20A856C891483ED63589F982  1DA2F6543A62B8ED934771661A9D2FA0
# 9   2D4B95E2FA7B2E85118EC5CA4570FA58  CD2F522EEE1FF5F5A8D8B679E23576B3
# 10  E12F6AF991172EAC3553144A0AF75A19  06918214E951FA0003D1CC54955C2AB0
#
#    vendor_id  rate_code store_and_fwd_flag      pickup_datetime  \
# 2        CMT          1                  N  2013-01-05 18:49:41
# 3        CMT          1                  N  2013-01-07 23:54:15
# ...

# %%
m.columns
# Out:
# Index([u'medallion_x', u'hack_license', u'vendor_id', u'rate_code', u'store_and_fwd_flag', u'pickup_datetime', u'dropoff_datetime', u'passenger_count', u'trip_time_in_secs', u'trip_distance', u'pickup_longitude', u'pickup_latitude', u'dropoff_longitude', u'dropoff_latitude', u'pickup_neighborhood', u'pickup_hour', u'dropoff_neighborhood', u'dropoff_hour', u'trip_id', u'medallion_y', u' hack_license', u' vendor_id', u' pickup_datetime', u' payment_type', u' fare_amount', u' surcharge', u' mta_tax', u' tip_amount', u' tolls_amount', u' total_amount'], dtype='object')

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()
# Out:
#                                      rate_code  passenger_count  \
# pickup_neighborhood
# Adelphi                               1.000000         1.875000
# Alphabet City                         1.039735         2.182119
# Astoria                               1.000000         2.081081
# Battery Park City                     1.049822         2.160142
# Bay Ridge                             1.000000         5.000000
# Bedford-Stuyvesant                    1.000000         2.666667
# Blissville                            2.600000         1.200000
# Boerum Hill                           1.000000         2.121212
# Borough Park                          1.000000         1.000000
# Broad Channel                         1.815642         2.117318
# Brooklyn Heights                      1.000000         2.000000
# Brooklyn Navy Yard                    1.166667         1.666667
# Brownsville                           1.000000         2.000000
# ...

# %%
m['payment_type'] = m[' payment_type']

# %%
m['fare_p'] = m[' tip_amount'] / m[' fare_amount']

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()
# Out:
#                                      rate_code  passenger_count  \
# pickup_neighborhood
# Adelphi                               1.000000         1.875000
# Alphabet City                         1.039735         2.182119
# Astoria                               1.000000         2.081081
# Battery Park City                     1.049822         2.160142
# Bay Ridge                             1.000000         5.000000
# Bedford-Stuyvesant                    1.000000         2.666667
# Blissville                            2.600000         1.200000
# Boerum Hill                           1.000000         2.121212
# Borough Park                          1.000000         1.000000
# Broad Channel                         1.815642         2.117318
# Brooklyn Heights                      1.000000         2.000000
# Brooklyn Navy Yard                    1.166667         1.666667
# Brownsville                           1.000000         2.000000
# ...

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').w()['fare_p']
# Out:
# pickup_neighborhood
# Adelphi                0.185790
# Alphabet City          0.185226
# Astoria                0.181130
# Battery Park City      0.180405
# Bay Ridge              0.254902
# Bedford-Stuyvesant     0.134482
# Blissville             0.198462
# Boerum Hill            0.178185
# Borough Park           0.323077
# Broad Channel          0.178883
# Brooklyn Heights       0.199633
# Brooklyn Navy Yard     0.185165
# Brownsville            0.000000
# Bushwick               0.182850
# Cedar Manor Houses     0.188268
# ...
# Unionport                    0.735632
# University Village           0.192384
# Upper East Side              0.188035
# Upper West Side              0.189818
# Washington Heights           0.166818
# Washington Square Village    0.191192
# Waterside Plaza              0.180729
# West Brighton                0.200000
# West New Brighton            0.250000
# Westerleigh                  3.998045
# Westgate Gardens             0.200000
# ...

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()['fare_p'].plot()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()['fare_p'].plot()

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()['fare_p'].bar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-e695d8519441> in <module>()
# ----> 1 m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()['fare_p'].bar
#
# /Users/billyshawsusanto/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'bar'

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').max()['fare_p']
# Out:
# pickup_neighborhood
# Adelphi                0.216667
# Alphabet City          1.212121
# Astoria                0.454545
# Battery Park City      0.500000
# Bay Ridge              0.254902
# Bedford-Stuyvesant     0.249600
# Blissville             0.200000
# Boerum Hill            0.500000
# Borough Park           0.323077
# Broad Channel          0.300000
# Brooklyn Heights       0.300000
# Brooklyn Navy Yard     0.204082
# Brownsville            0.000000
# Bushwick               0.216667
# Cedar Manor Houses     0.258621
# ...
# Unionport                     1.333333
# University Village            1.176471
# Upper East Side               1.025000
# Upper West Side               0.625000
# Washington Heights            0.300000
# Washington Square Village     1.090909
# Waterside Plaza               0.337500
# West Brighton                 0.200000
# West New Brighton             0.250000
# Westerleigh                  34.800000
# Westgate Gardens              0.200000
# ...

# %%
m.query("payment_type == 'CRD'").groupby('pickup_neighborhood').mean()['fare_p']
# Out:
# pickup_neighborhood
# Adelphi                0.185790
# Alphabet City          0.185226
# Astoria                0.181130
# Battery Park City      0.180405
# Bay Ridge              0.254902
# Bedford-Stuyvesant     0.134482
# Blissville             0.198462
# Boerum Hill            0.178185
# Borough Park           0.323077
# Broad Channel          0.178883
# Brooklyn Heights       0.199633
# Brooklyn Navy Yard     0.185165
# Brownsville            0.000000
# Bushwick               0.182850
# Cedar Manor Houses     0.188268
# ...
# Unionport                    0.735632
# University Village           0.192384
# Upper East Side              0.188035
# Upper West Side              0.189818
# Washington Heights           0.166818
# Washington Square Village    0.191192
# Waterside Plaza              0.180729
# West Brighton                0.200000
# West New Brighton            0.250000
# Westerleigh                  3.998045
# Westgate Gardens             0.200000
# ...

# %%
m.query("payment_type == 'CRD'")[['pickup_neighborhood', 'fare_p']].groupby('pickup_neighborhood').mean()
# Out:
#                                        fare_p
# pickup_neighborhood
# Adelphi                              0.185790
# Alphabet City                        0.185226
# Astoria                              0.181130
# Battery Park City                    0.180405
# Bay Ridge                            0.254902
# Bedford-Stuyvesant                   0.134482
# Blissville                           0.198462
# Boerum Hill                          0.178185
# Borough Park                         0.323077
# Broad Channel                        0.178883
# Brooklyn Heights                     0.199633
# Brooklyn Navy Yard                   0.185165
# Brownsville                          0.000000
# Bushwick                             0.182850
# Cedar Manor Houses                   0.188268
# Chelsea                              0.190686
# Chinatown                            0.179370
# Clinton                              0.197978
# Clinton Hill                         0.204325
# ...

# %%
m.groupby(['dropoff_neighborhood', 'payment_type']).count()
# Out:
#                                         medallion_x  hack_license  vendor_id  \
# dropoff_neighborhood      payment_type
# Adelphi                   CRD                    57            57         57
#                           CSH                    42            42         42
# Alphabet City             CRD                   300           300        300
#                           CSH                   216           216        216
# Annadale                  CRD                     1             1          1
# Arrochar                  CRD                     1             1          1
# Astoria                   CRD                   125           125        125
#                           CSH                   160           160        160
# Bath Beach                CRD                     1             1          1
#                           CSH                     2             2          2
# Battery Park City         CRD                   499           499        499
# ...

# %%
m.to_csv('merged_data_sample.csv')

# %%
import sckikit-learn
# Out:
#   File "<ipython-input-80-983a5f906e1a>", line 1
#     import sckikit-learn
#                   ^
# SyntaxError: invalid syntax

# %%
import sk-learn
# Out:
#   File "<ipython-input-81-c851b1ffd073>", line 1
#     import sk-learn
#              ^
# SyntaxError: invalid syntax

# %%
import sklearn

# %%
import statsmodels.formula.api as sm

# %%
result = sm.ols(formula="fare_p ~ trip_distance", data=m).fit()

# %%
result

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 fare_p   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     72.72
# Date:                Sat, 06 Dec 2014   Prob (F-statistic):           1.51e-17
# Time:                        12:27:53   Log-Likelihood:                 31614.
# No. Observations:               99999   AIC:                        -6.322e+04
# Df Residuals:                   99997   BIC:                        -6.321e+04
# Df Model:                           1
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         0.0933      0.001    128.494      0.000         0.092     0.095
# ...

# %%
result.
